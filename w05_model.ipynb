# %% [markdown]
# <a href="https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %% [markdown]
# ### Method choice
#
# I will use a Decision Tree classifier for this modeling task.
#
# A Decision Tree fits this lane because the target is a binary decline-detection label and the model can capture non-linear relationships between the available page-level signals and the label. It is also relatively easy to interpret, which is useful for understanding which signals are associated with the model's ranking.
#
# I will compare the model with the Week-4 hand-rule baseline using the same data split and Precision@K metric. The goal is not to reward a more complex model, but to check whether the learned model provides a useful improvement over the transparent baseline.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Check the current notebook variables
print("Available variables:")
print([name for name in globals() if not name.startswith("_")])
# Out:
# Available variables:
# ['In', 'Out', 'get_ipython', 'exit', 'quit', 'pd', 'np', 'train_test_split', 'DecisionTreeClassifier', 'precision_score']

# %% [markdown]
# ### Split design
#
# I will use the same train/test split as the Week-4 baseline so that the model is evaluated on the same data and under the same conditions.
#
# The split keeps the evaluation data separate from the training data. This avoids using test information while fitting the model and makes the comparison with the Week-4 baseline fair.
#
# The split design is fixed and reproducible using a random state.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# ### Train + compare vs my baseline
#
# I will train the Decision Tree using the same data and evaluation setup as the Week-4 baseline. I will compare both approaches using Precision@K on the same evaluation data.
#
# The comparison is intended to measure whether the learned model improves ranking quality over the simpler hand-rule baseline, rather than assuming that a more complex model is automatically better.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Step 3 — Train + compare against the Week-4 baseline

import os

print("Current directory:")
print(os.getcwd())

print("\nFiles in current directory:")
for file in os.listdir():
    print(file)
# Out:
# Current directory:
# /content
#
# Files in current directory:
# .config
# sample_data

# %% [markdown]
# ### Errors and interpretation
#
# I will inspect the cases where the model's prediction differs from the observed label. I will also examine feature importance to understand which available signals the Decision Tree relies on most.
#
# The interpretation will focus on observed patterns in the evaluation data. Feature importance will be treated as directional evidence rather than proof of causation.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
import os

print("Current folder:", os.getcwd())
print("\nAvailable dataset files:\n")

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith((".csv", ".parquet", ".xlsx")):
            print(os.path.join(root, file))
# Out:
# Current folder: /content
#
# Available dataset files:
#
# ./sample_data/mnist_train_small.csv
# ./sample_data/mnist_test.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/california_housing_train.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
