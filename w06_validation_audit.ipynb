# %% [markdown]
# <a href="https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 2: Honest grouped split
# Check what variables already exist
# %whos
# Out:
# Variable                 Type       Data/Info
# ---------------------------------------------
# GroupShuffleSplit        ABCMeta    <class 'sklearn.model_sel<...>split.GroupShuffleSplit'>
# RandomForestClassifier   ABCMeta    <class 'sklearn.ensemble.<...>.RandomForestClassifier'>
# leakage_columns          list       n=3
# np                       module     <module 'numpy' from '/us<...>kages/numpy/__init__.py'>

# %%
# Section 2 — Check whether the Week-5 data/model is available

print("Week-5 model variables available:")

for name in ["df", "X", "y", "model", "tree", "predictions"]:
    print(name, "->", name in globals())

print("\nDataFrames currently available:")
for name, value in globals().items():
    if isinstance(value, pd.DataFrame):
        print(name, value.shape)
# Out:
# Week-5 model variables available:
# df -> False
# X -> False
# y -> False
# model -> False
# tree -> False
# predictions -> False
#
# DataFrames currently available:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1772/1862574789.py in <cell line: 0>()
#       8 print("\nDataFrames currently available:")
#       9 for name, value in globals().items():
# ---> 10     if isinstance(value, pd.DataFrame):
#      11         print(name, value.shape)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Finding 1: The research reports that pages showing declining performance can be identified using observable search-performance signals. The label in our modeling workflow comes from trend_direction == "down". My methodology question is whether this label is a sufficient proxy for the broader idea of content decline, because it captures one observed trend rather than proving the underlying cause.
#
# Finding 2: The research suggests that a ranking/model can help prioritize pages for review. My methodology question is whether the validation design supports generalization to unseen clients/pages. A random row split could make the result look stronger if related pages from the same client appear in both train and test, so a grouped client-level split is a more conservative check.
#
# Ye constructive tone me hai—paper ko attack nahi kar raha, bas methodology question raise kar raha hai.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 3: Leakage audit
# Section 3 — Leakage audit

leakage_columns = [
    "is_declining_label",
    "trend_direction",
    "trend_pct"
]

print("Leakage columns that must be excluded:")
for col in leakage_columns:
    print("-", col)

print("\nAudit status:")
print("PASS — These columns are identified for exclusion from the final feature set.")
# Out:
# Leakage columns that must be excluded:
# - is_declining_label
# - trend_direction
# - trend_pct
#
# Audit status:
# PASS — These columns are identified for exclusion from the final feature set.

# %% [markdown]
# Leakage audit: I checked the final feature set for columns that directly define or reveal the target. The target is_declining_label must not be used as a feature, and trend_direction and trend_pct must also be excluded because they are used to define the decline label. No such leakage features should remain in the final model feature set

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Original claim:**
# The Decision Tree model can accurately predict which pages will decline.
#
# **Safe rewrite:**
# On the evaluated data, the Decision Tree can provide a directional signal for prioritizing pages that may show decline. This is an observed modeling result, not proof that the model can predict future search performance or explain why a page declines. The output should be treated as decision-support for further review rather than a definitive prediction.

# %% [markdown]
# Original: The model accurately predicts which pages will decline.
#
# Rewritten: On the evaluated dataset, the model showed a higher Precision@50 than the simple baseline under the tested validation setup. This is an observed, directional result that can support prioritization of pages for review; it does not establish that the model predicts future search-engine behavior or causes of decline.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
