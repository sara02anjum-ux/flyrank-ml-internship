# %% [markdown]
# <a href="https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Content refresh prioritization. I want to identify which pages may be worth reviewing or refreshing based on observable search and content signals. I chose this lane because the starter data contains page-level signals such as impressions, position, CTR, content age, and update recency, and the first notebooks showed that simple rules can identify useful patterns. Over the next 7 weeks, I want to investigate whether these signals can support better, more consistent refresh decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should be prioritized for a content refresh review? Action: An SEO or content team member could review the highest-priority pages and decide whether to update, improve, or leave them unchanged. Cost of a wrong call: Prioritizing a page that does not need a refresh can waste time and resources, while missing a page that is actually declining could mean losing potential search visibility and traffic. The goal is therefore to support the team's prioritization decision, not to automatically decide which pages must be changed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 pages. The median number of impressions over 90 days is 731, and the median number of days since the last update is 20 days. These numbers show that the dataset contains a substantial number of pages with measurable search visibility and information about content freshness. This makes content refresh prioritization a useful question to investigate further. These numbers are descriptive of the starter dataset and do not by themselves prove that refreshing a page will improve its performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd
import subprocess
import sys

REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run([
        "git", "clone", "--depth", "1",
        "https://github.com/flyrank-bih/flyrank-ml-internship-starter",
        REPO_DIR
    ], check=True)

df = pd.read_csv(
    f"{REPO_DIR}/data/raw/content_refresh_anonymized.csv"
)

print("Total pages:", len(df))
print("Median impressions (90d):", df["impressions_90d"].median())
print("Median days since last update:", df["days_since_last_update"].median())
# Out:
# Total pages: 30000
# Median impressions (90d): 731.0
# Median days since last update: 20.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can use the data to describe observed patterns and measured relationships between page-level signals and content performance. The results can provide directional evidence and decision-support for prioritizing pages for review. However, I cannot claim that a specific content change will cause traffic or rankings to improve, and I cannot claim to predict Google's ranking decisions. Any model I build should be treated as a tool to support human decisions, not as proof of causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
