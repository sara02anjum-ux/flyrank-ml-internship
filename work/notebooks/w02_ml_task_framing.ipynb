# %% [markdown]
# <a href="https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sara02anjum-ux/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My lane is content refresh prioritization. The goal is to rank pages by how strongly they should be considered for review or refresh. The output would help a content team decide which pages to look at first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A page-level declining-content signal derived from observed trend direction. This acts as a proxy for whether a page may be worth reviewing for a content refresh.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I care about how many of the top 50 prioritized pages are actually relevant for review. This matches the real decision because the content team needs a useful shortlist rather than a list of every page.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content/flyrank-ml-internship-starter
# ['SETUP.md', 'outputs', 'README.md', '.git', 'submission', 'GUIDE.md', 'AGENTS.md', 'skills', 'notebooks', 'DATA_USE.md', '.github', 'data', 'CLAUDE.md', 'requirements.txt', 'work', 'scripts', 'LICENSE', '.gitignore', 'docs']

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 283 (delta 112), reused 83 (delta 83), pack-reused 138 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 5.21 MiB/s, done.
# Resolving deltas: 100% (153/153), done.

# %%
# %cd flyrank-ml-internship-starter
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
# !ls data/raw
# Out:
# content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.shape
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %%
df[[
    'content_id',
    'client_id',
    'content_type',
    'search_volume',
    'impressions_90d',
    'clicks_90d',
    'content_age_days',
    'days_since_last_update',
    'ctr',
    'avg_position'
]].head()
# Out:
#              content_id          client_id     content_type  search_volume  \
# 0  content_304f48230142  client_f369cb89fc  keyword article           10.0
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article           90.0
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article            0.0
# 3  content_331d6c4de07b  client_19581e27de  keyword article           10.0
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article            0.0
#
#    impressions_90d  clicks_90d  content_age_days  days_since_last_update  \
# 0             3803          29               187                      20
# 1            15320           7               445                      25
# 2            12581          11               141                      20
# 3            11751          58               463                      22
# 4            19140          24               263                      14
#
#     ctr  avg_position
# 0  0.76          10.6
# 1  0.05          20.3
# ...

# %% [markdown]
# The unit of analysis is one content page. Each row represents one page for a client, with its search demand, traffic performance, content age, freshness, and search visibility signals.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule would require choosing thresholds for several signals, such as content age, impressions, CTR, and average position. These signals can interact in different ways, so one simple rule may miss useful combinations. ML can learn patterns across these signals and help prioritize pages based on multiple factors rather than one fixed threshold.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
